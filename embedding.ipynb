# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
###Sentences
sent =['the glass of milk',
       'the glass of juice',
       'the cup of tea', 
       'I am a good boy',
       'I am a good developer',
       'understanding the meaning of words',
       'your videos are good',
]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understanding the meaning of words',
#  'your videos are good']

# %%
##Define the vocabulary
voc_size = 10000

# %%
##One Hot Representation
one_hot_repr = [one_hot(words,voc_size)for words in sent]
one_hot_repr
# Out:
# [[1883, 1875, 3483, 829],
#  [1883, 1875, 3483, 1518],
#  [1883, 8300, 3483, 6582],
#  [5530, 228, 4151, 928, 925],
#  [5530, 228, 4151, 928, 1524],
#  [5356, 1883, 164, 3483, 2752],
#  [4869, 6127, 7165, 928]]

# %%
# word Embedding Representation

from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length = 8
embedded_docs = pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 1883 1875 3483  829]
#  [   0    0    0    0 1883 1875 3483 1518]
#  [   0    0    0    0 1883 8300 3483 6582]
#  [   0    0    0 5530  228 4151  928  925]
#  [   0    0    0 5530  228 4151  928 1524]
#  [   0    0    0 5356 1883  164 3483 2752]
#  [   0    0    0    0 4869 6127 7165  928]]

# %%
##feature representation
dim=10

# %%
model = Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# c:\installs\Anaconda\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.build(input_shape=(None, sent_length))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 8, 10)          │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 1883, 1875, 3483,  829])

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# array([[[ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.04846552,  0.04849246,  0.00335366, -0.03692447,
#          -0.01873431, -0.04310254, -0.02402752,  0.01364757,
#          -0.04825021,  0.03358707],
#         [-0.01487232, -0.04254901, -0.04099352, -0.01092126,
#           0.04661634, -0.03981037,  0.04207045, -0.0183607 ,
#           0.00896881,  0.01462561],
#         [-0.03467013,  0.02833494, -0.00965958, -0.03722547,
#          -0.03732822, -0.04599377, -0.01419321,  0.00850608,
#          -0.03585277, -0.01350764],
#         [-0.02790326, -0.02826231, -0.00364504,  0.04193325,
#           0.01042709,  0.04437048,  0.019604  ,  0.02101685,
#           0.02650156, -0.01433905]],
#
#        [[ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.04846552,  0.04849246,  0.00335366, -0.03692447,
#          -0.01873431, -0.04310254, -0.02402752,  0.01364757,
#          -0.04825021,  0.03358707],
#         [-0.01487232, -0.04254901, -0.04099352, -0.01092126,
#           0.04661634, -0.03981037,  0.04207045, -0.0183607 ,
#           0.00896881,  0.01462561],
#         [-0.03467013,  0.02833494, -0.00965958, -0.03722547,
#          -0.03732822, -0.04599377, -0.01419321,  0.00850608,
#          -0.03585277, -0.01350764],
#         [-0.02051252, -0.04609701,  0.02594442, -0.00909492,
#           0.00922127, -0.02456549, -0.00506797,  0.04853049,
#           0.03474863,  0.01444923]],
#
#        [[ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.04846552,  0.04849246,  0.00335366, -0.03692447,
#          -0.01873431, -0.04310254, -0.02402752,  0.01364757,
#          -0.04825021,  0.03358707],
#         [-0.00219794,  0.01108668,  0.03240032, -0.03187495,
#           0.0304768 , -0.039717  , -0.02049105, -0.02053026,
#           0.04449488,  0.02276104],
#         [-0.03467013,  0.02833494, -0.00965958, -0.03722547,
#          -0.03732822, -0.04599377, -0.01419321,  0.00850608,
#          -0.03585277, -0.01350764],
#         [-0.02783747, -0.03175863, -0.03471749, -0.01102759,
#           0.01764181, -0.04167789,  0.03163675, -0.03738954,
#          -0.0096425 , -0.02306241]],
#
#        [[ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.01457313,  0.01935485, -0.03061599, -0.00380244,
#          -0.02832052, -0.04847642,  0.03364008, -0.0066031 ,
#           0.01863389,  0.0256854 ],
#         [-0.03534042, -0.01316814, -0.01491386,  0.04217404,
#           0.00409193, -0.03066024, -0.01194707,  0.04325065,
#           0.0138087 , -0.00395923],
#         [-0.0307791 ,  0.00125381, -0.02126914,  0.03060937,
#          -0.00815097, -0.04975891,  0.0045356 , -0.01725   ,
#           0.01276581, -0.04656578],
#         [ 0.02123237, -0.02992224, -0.02801837, -0.0063324 ,
#          -0.03496303,  0.02754264, -0.03577041,  0.01005946,
#           0.0332016 ,  0.04447163],
#         [ 0.04972457, -0.01693704, -0.02791281,  0.03098157,
#           0.02437312, -0.00341941,  0.00781742,  0.04312612,
#          -0.04780438,  0.02048892]],
#
#        [[ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.01457313,  0.01935485, -0.03061599, -0.00380244,
#          -0.02832052, -0.04847642,  0.03364008, -0.0066031 ,
#           0.01863389,  0.0256854 ],
#         [-0.03534042, -0.01316814, -0.01491386,  0.04217404,
#           0.00409193, -0.03066024, -0.01194707,  0.04325065,
#           0.0138087 , -0.00395923],
#         [-0.0307791 ,  0.00125381, -0.02126914,  0.03060937,
#          -0.00815097, -0.04975891,  0.0045356 , -0.01725   ,
#           0.01276581, -0.04656578],
#         [ 0.02123237, -0.02992224, -0.02801837, -0.0063324 ,
#          -0.03496303,  0.02754264, -0.03577041,  0.01005946,
#           0.0332016 ,  0.04447163],
#         [-0.01583757,  0.02534455,  0.00593973, -0.03434299,
#          -0.0240629 , -0.02945116,  0.04358565,  0.02980682,
#           0.01561965,  0.04887563]],
#
#        [[ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [-0.02255334,  0.01237831,  0.02518555,  0.014358  ,
#           0.01194795,  0.024934  , -0.01978458, -0.0460991 ,
#           0.013272  , -0.03157985],
#         [ 0.04846552,  0.04849246,  0.00335366, -0.03692447,
#          -0.01873431, -0.04310254, -0.02402752,  0.01364757,
#          -0.04825021,  0.03358707],
#         [-0.00599071, -0.03508468,  0.01719001, -0.03830414,
#          -0.04784402,  0.0440591 , -0.01591212,  0.01730564,
#          -0.03007611, -0.01655829],
#         [-0.03467013,  0.02833494, -0.00965958, -0.03722547,
#          -0.03732822, -0.04599377, -0.01419321,  0.00850608,
#          -0.03585277, -0.01350764],
#         [ 0.01066847,  0.03513369,  0.01704956,  0.03991841,
#           0.0178966 ,  0.0092762 , -0.00805131,  0.04044569,
#          -0.01646911, -0.0307839 ]],
#
#        [[ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.01398813,  0.04342167, -0.01799824,  0.0299911 ,
#          -0.02713105, -0.02691349, -0.04182844, -0.01788978,
#           0.01850123,  0.0004001 ],
#         [ 0.03725845, -0.03427811,  0.00164095, -0.04682475,
#           0.03183565,  0.0166646 , -0.0087286 , -0.04807476,
#           0.01411081, -0.04436129],
#         [ 0.01155914, -0.0120154 , -0.04088103, -0.01318945,
#           0.0441376 , -0.00289713, -0.03490062, -0.00702507,
#          -0.04875363, -0.0174026 ],
#         [-0.03901434, -0.01397405,  0.04967269,  0.01375229,
#          -0.01726682, -0.00152166,  0.0393482 , -0.00371997,
#          -0.03405186,  0.04438896],
#         [ 0.02123237, -0.02992224, -0.02801837, -0.0063324 ,
#          -0.03496303,  0.02754264, -0.03577041,  0.01005946,
#           0.0332016 ,  0.04447163]]], dtype=float32)
